# %%
import numpy as np
import sys
sys.path.append("..")
from solvers.ga.ga_solver import GeneticAlgorithmSolver
from problem.sudoku_manager import Sudoku, generate_boards

# %%
generate_boards(5, 'medium')

# %%
sud = Sudoku('easy', 34)
# Out:
# There is no board with level: easy and board_id: 60: [Errno 2] No such file or directory: '/Users/janekkuc/Desktop/PW/Sem7/POP/POP_22Z/src/tests/../problem/sudoku_boards/easy/sudoku_easy_60.npy'

# %%
new_solver = GeneticAlgorithmSolver(sud, pop_size=500, chrom_size=12, pc=0.8, pm=0.15, t_max=800)
sud.board
# Out:
# array([[0, 0, 5, 4, 0, 1, 2, 0, 6],
#        [4, 0, 0, 0, 0, 7, 0, 3, 0],
#        [0, 7, 0, 0, 5, 6, 8, 0, 0],
#        [1, 2, 3, 0, 9, 4, 0, 6, 7],
#        [8, 9, 0, 7, 0, 5, 0, 0, 0],
#        [6, 5, 0, 0, 0, 0, 0, 0, 9],
#        [2, 1, 0, 3, 4, 9, 7, 0, 0],
#        [0, 4, 8, 0, 0, 0, 0, 0, 1],
#        [7, 0, 0, 5, 0, 0, 0, 0, 2]])

# %%
results = new_solver.solve()
# Out:
# I: 0 best: 198 max: 198
# Improvement! Score: 200
# I: 1 best: 200 max: 200
# Improvement! Score: 202
# I: 2 best: 202 max: 202
# Improvement! Score: 204
# I: 3 best: 204 max: 204
# I: 4 best: 204 max: 203
# Improvement! Score: 206
# I: 5 best: 206 max: 206
# I: 6 best: 206 max: 206
# Improvement! Score: 207
# I: 7 best: 207 max: 207
# I: 8 best: 207 max: 207
# Improvement! Score: 211
# I: 9 best: 211 max: 211
# I: 10 best: 211 max: 211
# I: 11 best: 211 max: 210
# I: 12 best: 211 max: 211
# Improvement! Score: 217
# I: 13 best: 217 max: 217
# I: 14 best: 217 max: 210
# I: 15 best: 217 max: 213
# I: 16 best: 217 max: 215
# I: 17 best: 217 max: 216
# I: 18 best: 217 max: 214
# I: 19 best: 217 max: 213
# I: 20 best: 217 max: 214
# I: 21 best: 217 max: 215
# I: 22 best: 217 max: 211
# I: 23 best: 217 max: 212
# I: 24 best: 217 max: 213
# I: 25 best: 217 max: 212
# I: 26 best: 217 max: 212
# I: 27 best: 217 max: 217
# I: 28 best: 217 max: 217
# I: 29 best: 217 max: 217
# ...

# %%
best_chrom, score_best_global, best_per_iter = results

# %%
best_chrom
# Out:
# array([[8, 9, 5, 4, 3, 1, 2, 7, 6],
#        [4, 1, 6, 8, 2, 7, 9, 3, 5],
#        [3, 7, 2, 4, 5, 6, 8, 1, 9],
#        [1, 2, 3, 8, 9, 4, 5, 6, 7],
#        [8, 9, 1, 7, 6, 5, 4, 2, 3],
#        [6, 5, 7, 2, 8, 3, 1, 4, 9],
#        [2, 1, 5, 3, 4, 9, 7, 8, 6],
#        [5, 4, 8, 6, 7, 2, 3, 9, 1],
#        [7, 6, 9, 5, 1, 8, 4, 3, 2]])
